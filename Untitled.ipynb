# %%
import pandas as pd
df = pd.read_csv("pokeman_data.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22372\2326934783.py in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("pokeman_data.csv")
#       3 print(df)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd 
df = pd.read_csv('pokeman_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22372\1104009532.py in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('pokeman_data.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd 
df = pd.read_csv('pokemon_data.csv')

#(excel files can be read by using )
# df_xlsx = pd.read_xlsx('pokemon_data.xlsx')

#(txt files can be used by using below code)
#df_txt = pd.read_txt('pokemon_data.txt')

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df.[["name", "type1","HP"]])
# Out:
#   File "C:\Users\katuk\AppData\Local\Temp\ipykernel_22372\3573125313.py", line 1
#     print(df.[["name", "type1","HP"]])
#              ^
# SyntaxError: invalid syntax

# %%
print(df.[["Name", "Type 1","HP"]])
# Out:
#   File "C:\Users\katuk\AppData\Local\Temp\ipykernel_22372\2596488733.py", line 1
#     print(df.[["Name", "Type 1","HP"]])
#              ^
# SyntaxError: invalid syntax

# %%
print(df[["Name", "Type 1","HP"]])
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
print(df.iloc[0:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
for index, row in df.itertows():
    print(index, row["Name"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22372\2775228916.py in <module>
# ----> 1 for index, row in df.itertows():
#       2     print(index, row["Name"])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'itertows'

# %%
for index, row in df.iterrows():
    print(index, row["Type 1"])
# Out:
# 0 Grass
# 1 Grass
# 2 Grass
# 3 Grass
# 4 Fire
# 5 Fire
# 6 Fire
# 7 Fire
# 8 Fire
# 9 Water
# 10 Water
# 11 Water
# 12 Water
# 13 Bug
# 14 Bug
# 15 Bug
# 16 Bug
# 17 Bug
# 18 Bug
# 19 Bug
# 20 Normal
# 21 Normal
# 22 Normal
# 23 Normal
# 24 Normal
# 25 Normal
# 26 Normal
# 27 Normal
# 28 Poison
# 29 Poison
# 30 Electric
# 31 Electric
# 32 Ground
# 33 Ground
# 34 Poison
# 35 Poison
# 36 Poison
# 37 Poison
# 38 Poison
# 39 Poison
# 40 Fairy
# 41 Fairy
# 42 Fire
# 43 Fire
# 44 Normal
# 45 Normal
# 46 Poison
# 47 Poison
# 48 Grass
# 49 Grass
# 50 Grass
# 51 Bug
# 52 Bug
# 53 Bug
# 54 Bug
# 55 Ground
# 56 Ground
# 57 Normal
# 58 Normal
# 59 Water
# 60 Water
# 61 Fighting
# 62 Fighting
# 63 Fire
# 64 Fire
# 65 Water
# 66 Water
# 67 Water
# 68 Psychic
# 69 Psychic
# 70 Psychic
# 71 Psychic
# 72 Fighting
# 73 Fighting
# 74 Fighting
# 75 Grass
# 76 Grass
# 77 Grass
# 78 Water
# 79 Water
# 80 Rock
# 81 Rock
# 82 Rock
# 83 Fire
# 84 Fire
# 85 Water
# 86 Water
# 87 Water
# 88 Electric
# ...

# %%
for index, row in df.iterrows():
    print(index, row["HP"])
# Out:
# 0 45
# 1 60
# 2 80
# 3 80
# 4 39
# 5 58
# 6 78
# 7 78
# 8 78
# 9 44
# 10 59
# 11 79
# 12 79
# 13 45
# 14 50
# 15 60
# 16 40
# 17 45
# 18 65
# 19 65
# 20 40
# 21 63
# 22 83
# 23 83
# 24 30
# 25 55
# 26 40
# 27 65
# 28 35
# 29 60
# 30 35
# 31 60
# 32 50
# 33 75
# 34 55
# 35 70
# 36 90
# 37 46
# 38 61
# 39 81
# 40 70
# 41 95
# 42 38
# 43 73
# 44 115
# 45 140
# 46 40
# 47 75
# 48 45
# 49 60
# 50 75
# 51 35
# 52 60
# 53 60
# 54 70
# 55 10
# 56 35
# 57 40
# 58 65
# 59 50
# 60 80
# 61 40
# 62 65
# 63 55
# 64 90
# 65 40
# 66 65
# 67 90
# 68 25
# 69 40
# 70 55
# 71 55
# 72 70
# 73 80
# 74 90
# 75 50
# 76 65
# 77 80
# 78 40
# 79 80
# 80 40
# 81 55
# 82 80
# 83 50
# 84 65
# 85 90
# 86 95
# 87 95
# 88 25
# 89 50
# 90 52
# 91 35
# 92 60
# 93 65
# 94 90
# 95 80
# 96 105
# 97 30
# 98 50
# 99 30
# 100 45
# 101 60
# 102 60
# 103 35
# 104 60
# 105 85
# 106 30
# 107 55
# 108 40
# 109 60
# 110 60
# 111 95
# 112 50
# 113 60
# 114 50
# 115 50
# 116 90
# 117 40
# 118 65
# 119 80
# 120 105
# 121 250
# ...

# %%
print(df.loc[df["Type 1"] == "Fire"])
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
print(df.loc[df["Type 1"]=="Fire"])
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
print(df.iloc[2,3])
# Out:
# Poison

# %%
for index, row in df.iterrows():
    print(index, row['HP'])
# Out:
# 0 45
# 1 60
# 2 80
# 3 80
# 4 39
# 5 58
# 6 78
# 7 78
# 8 78
# 9 44
# 10 59
# 11 79
# 12 79
# 13 45
# 14 50
# 15 60
# 16 40
# 17 45
# 18 65
# 19 65
# 20 40
# 21 63
# 22 83
# 23 83
# 24 30
# 25 55
# 26 40
# 27 65
# 28 35
# 29 60
# 30 35
# 31 60
# 32 50
# 33 75
# 34 55
# 35 70
# 36 90
# 37 46
# 38 61
# 39 81
# 40 70
# 41 95
# 42 38
# 43 73
# 44 115
# 45 140
# 46 40
# 47 75
# 48 45
# 49 60
# 50 75
# 51 35
# 52 60
# 53 60
# 54 70
# 55 10
# 56 35
# 57 40
# 58 65
# 59 50
# 60 80
# 61 40
# 62 65
# 63 55
# 64 90
# 65 40
# 66 65
# 67 90
# 68 25
# 69 40
# 70 55
# 71 55
# 72 70
# 73 80
# 74 90
# 75 50
# 76 65
# 77 80
# 78 40
# 79 80
# 80 40
# 81 55
# 82 80
# 83 50
# 84 65
# 85 90
# 86 95
# 87 95
# 88 25
# 89 50
# 90 52
# 91 35
# 92 60
# 93 65
# 94 90
# 95 80
# 96 105
# 97 30
# 98 50
# 99 30
# 100 45
# 101 60
# 102 60
# 103 35
# 104 60
# 105 85
# 106 30
# 107 55
# 108 40
# 109 60
# 110 60
# 111 95
# 112 50
# 113 60
# 114 50
# 115 50
# 116 90
# 117 40
# 118 65
# 119 80
# 120 105
# 121 250
# ...

# %%
print(df[['Name','Type 1']])
# Out:
#                       Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]

# %%
print(df.iloc[0,3])
# Out:
# Poison

# %%
df.sort_values(['Type 1'], ascending=False)
# Out:
#        #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 371  339  Barboach  Water  Ground  50      48       43       46       41
# 97    90  Shellder  Water     NaN  30      65      100       45       25
# 240  222   Corsola  Water    Rock  55      55       85       65       85
# 403  368  Gorebyss  Water     NaN  55      84      105      114       75
# 93    86      Seel  Water     NaN  65      45       55       45       70
# ..   ...       ...    ...     ...  ..     ...      ...      ...      ...
# 54    49  Venomoth    Bug  Poison  70      65       60       90       75
# 208  193     Yanma    Bug  Flying  65      65       45       75       45
# 182  168   Ariados    Bug  Poison  70      90       70       60       60
# 734  666  Vivillon    Bug  Flying  80      52       50       90       50
# 179  165    Ledyba    Bug  Flying  40      20       30       40       80
#
#      Speed  Generation  Legendary
# 371     60           3      False
# ...

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df.drop(columns=["Name"])
df.head(5)
# Out:
#    #                   Name  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1              Bulbasaur  Poison  45      49       49       65       65
# 1  2                Ivysaur  Poison  60      62       63       80       80
# 2  3               Venusaur  Poison  80      82       83      100      100
# 3  3  VenusaurMega Venusaur  Poison  80     100      123      122      120
# 4  4             Charmander     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary  Total
# 0     45           1      False    273
# 1     60           1      False    345
# 2     80           1      False    445
# 3     80           1      False    545
# 4     65           1      False    270

# %%
# df = df.drop(columns=["Type 1"])
# df.head(5)
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(5)
# Out:
#    #                   Name  Type 2  HP  Total  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Poison  45    274      49       49       65
# 1  2                Ivysaur  Poison  60    346      62       63       80
# 2  3               Venusaur  Poison  80    446      82       83      100
# 3  3  VenusaurMega Venusaur  Poison  80    546     100      123      122
# 4  4             Charmander     NaN  39    271      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    274
# 1       80     60           1      False    346
# 2      100     80           1      False    446
# 3      120     80           1      False    546
# 4       50     65           1      False    271

# %%
cols = list(df.columns)
print(cols)
# Out:
# ['#', 'Name', 'Type 2', 'HP', 'Total', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total']

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(5)
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(5)
# Out:
#    #                   Name  Type 2  HP    Total    Total    Total    Total  \
# 0  1              Bulbasaur  Poison  45   5545.0   5545.0   5545.0   5545.0
# 1  2                Ivysaur  Poison  60   7000.0   7000.0   7000.0   7000.0
# 2  3               Venusaur  Poison  80   9020.0   9020.0   9020.0   9020.0
# 3  3  VenusaurMega Venusaur  Poison  80  11040.0  11040.0  11040.0  11040.0
# 4  4             Charmander     NaN  39   5470.0   5470.0   5470.0   5470.0
#
#      Total    Total  ...    Total    Total    Total    Total    Total  \
# 0   5545.0   5545.0  ...   5545.0   5545.0   5545.0   5545.0   5545.0
# 1   7000.0   7000.0  ...   7000.0   7000.0   7000.0   7000.0   7000.0
# 2   9020.0   9020.0  ...   9020.0   9020.0   9020.0   9020.0   9020.0
# 3  11040.0  11040.0  ...  11040.0  11040.0  11040.0  11040.0  11040.0
# 4   5470.0   5470.0  ...   5470.0   5470.0   5470.0   5470.0   5470.0
#
#      Total    Total    Total    Total    Total
# ...

# %%
# df.to_csv('modified.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22372\159574771.py in <module>
# ----> 1 df.to_csv('modified.csv', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ...

# %%
new_df = df.loc[df["HP"]>70]
new_df = new_df.reset_index(drop=True)
print(new_df)
# new_df.to_csv("Filterd")
# Out:
#        #                       Name  Type 2   HP    Total    Total    Total  \
# 0      3                   Venusaur  Poison   80   9020.0   9020.0   9020.0
# 1      3      VenusaurMega Venusaur  Poison   80  11040.0  11040.0  11040.0
# 2      6                  Charizard  Flying   78   9225.0   9225.0   9225.0
# 3      6  CharizardMega Charizard X  Dragon   78  11225.0  11225.0  11225.0
# 4      6  CharizardMega Charizard Y  Flying   78  11255.0  11255.0  11255.0
# ..   ...                        ...     ...  ...      ...      ...      ...
# 316  717                    Yveltal  Flying  126  11303.0  11303.0  11303.0
# 317  718           Zygarde50% Forme  Ground  108  10060.0  10060.0  10060.0
# 318  720        HoopaHoopa Confined   Ghost   80  10655.0  10655.0  10655.0
# 319  720         HoopaHoopa Unbound    Dark   80  12255.0  12255.0  12255.0
# 320  721                  Volcanion   Water   80  10615.0  10615.0  10615.0
#
# ...

# %%
df.loc[~df['Name'].str.contains("Mega")]
# Out:
#        #                 Name  Type 2   HP    Total    Total    Total  \
# 0      1            Bulbasaur  Poison   45   5545.0   5545.0   5545.0
# 1      2              Ivysaur  Poison   60   7000.0   7000.0   7000.0
# 2      3             Venusaur  Poison   80   9020.0   9020.0   9020.0
# 4      4           Charmander     NaN   39   5470.0   5470.0   5470.0
# 5      5           Charmeleon     NaN   58   7025.0   7025.0   7025.0
# ..   ...                  ...     ...  ...      ...      ...      ...
# 794  718     Zygarde50% Forme  Ground  108  10060.0  10060.0  10060.0
# 795  719              Diancie   Fairy   50  11275.0  11275.0  11275.0
# 797  720  HoopaHoopa Confined   Ghost   80  10655.0  10655.0  10655.0
# 798  720   HoopaHoopa Unbound    Dark   80  12255.0  12255.0  12255.0
# 799  721            Volcanion   Water   80  10615.0  10615.0  10615.0
#
#        Total    Total    Total  ...    Total    Total    Total    Total  \
# ...
